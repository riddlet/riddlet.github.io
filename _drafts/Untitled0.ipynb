# %%
import pandas as pd
import numpy as np
from ggplot import *
import glob
import csv

# %matplotlib inline

# %%
#get list of files
files = glob.glob('Scopus-*.csv')
for i, f in enumerate(files):
    data[i] = pd.read_csv(f, skiprows=7)

# %%
data
# Out:
# array([                                           SOURCE TITLE  Unnamed: 1
# 0                                Psychological Reports         508
# 1                          Perceptual and Motor Skills         484
# 2    Zhurnal Nevropatologii I Psikhiatrii Imeni S S...         351
# 3                          Social Science and Medicine         338
# 4     Journal of Neurology Neurosurgery and Psychiatry         321
# 5                       Journal of Clinical Psychiatry         307
# 6                                American Psychologist         215
# 7         Journal of Personality and Social Psychology         208
# 8    Journal of the American Academy of Child and A...         202
# 9                                                 Pain         192
# 10              Personality and Individual Differences         187
# 11                              Advances in Psychology         186
# 12        Japanese Journal of Psychiatry and Neurology         180
# ...

# %%
len(data[4])
# Out:
# 158
